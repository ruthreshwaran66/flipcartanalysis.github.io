# %% [markdown]
# # **About Dataset**
#   The dataset is gathered using a scrapper from Flipkart. It contains information about the products that are being sold in Flipkart. You can read more about the data and the process of scrapping on this medium article.
# The features of this dataset includes -
#
#
#
# *   Category1, Category2, Category 3 : Specifies the division in which the   data belongs as per the website.
# *   Title : Title of the product.
# *   Product Rating : Customer based rating of the product.
# *   Selling Price : Price at which the product was being sold on the date of scrapping.
#
# *   MRP : MRP of the product.
# *   Seller Name : Name of the business selling the product.
#
# *   Seller Rating : Rating of the same seller based on the customers.
# *   Description : Description of product if available.
#
# *   Highlights : Highlights of the product if available.
# *   Image Links : Image link of the product.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fb_df=pd.read_csv('/content/dataset.csv')

# %%
fb_df.head()
# Out:
#                category_1 category_2 category_3  \
# 0  Sports, Books and More     Sports   Cricket
# 1  Sports, Books and More     Sports   Cricket
# 2  Sports, Books and More     Sports   Cricket
# 3  Sports, Books and More     Sports   Cricket
# 4  Sports, Books and More     Sports   Cricket
#
#                                                title  product_rating  \
# 0  ITWOSERVICES CRICKET NET 100X10 CRICKET NET NY...             4.4
# 1  ITWOSERVICES CRICKET NET GROUND BOUNDARY NET 1...             4.4
# 2  VICTORY Medium Weight ( Pack of 1 ) Rubber Cri...             3.7
# 3  VICTORY Cricket Wind Ball (Pack of 1) - Made i...             3.8
# 4  CEAT Hitman Full Size Double Blade Poplar Cric...             3.4
#
#   selling_price     mrp     seller_name  seller_rating  \
# 0        ₹1,615  ₹4,000      I2SERVICES            4.4
# 1          ₹152    ₹600      I2SERVICES            4.4
# 2           ₹59    ₹199  VictoryOutlets            4.7
# ...

# %%
fb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12041 entries, 0 to 12040
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   category_1      12041 non-null  object
#  1   category_2      12041 non-null  object
#  2   category_3      12041 non-null  object
#  3   title           12023 non-null  object
#  4   product_rating  11961 non-null  float64
#  5   selling_price   12013 non-null  object
#  6   mrp             11666 non-null  object
#  7   seller_name     11825 non-null  object
#  8   seller_rating   11827 non-null  float64
#  9   description     5021 non-null   object
#  10  highlights      6560 non-null   object
#  11  image_links     12041 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 1.1+ MB

# %%
fb_df.dtypes
# Out:
# category_1         object
# category_2         object
# category_3         object
# title              object
# product_rating    float64
# selling_price      object
# mrp                object
# seller_name        object
# seller_rating     float64
# description        object
# highlights         object
# image_links        object
# dtype: object

# %%
fb_df.describe()
# Out:
#        product_rating  seller_rating
# count    11961.000000   11827.000000
# mean         4.061617       4.394538
# std          0.345575       0.404288
# min          1.000000       3.000000
# 25%          3.900000       4.100000
# 50%          4.100000       4.400000
# 75%          4.300000       4.700000
# max          5.000000       5.000000

# %%
fb_df.isnull().sum()
# Out:
# category_1           0
# category_2           0
# category_3           0
# title               18
# product_rating      80
# selling_price       28
# mrp                375
# seller_name        216
# seller_rating      214
# description       7020
# highlights        5481
# image_links          0
# dtype: int64

# %%
fb_df[fb_df['title'].isnull()]
# Out:
#                    category_1                     category_2  \
# 310    Sports, Books and More              Exercise Fitness
# 681    Sports, Books and More                Food Essentials
# 1578   Sports, Books and More  Industrial &Scientific tools
# 1936              Electronics             Mobile Accessories
# 2164              Electronics            Smart Wearable Tech
# 3557               Men's wear                    Bottom Wear
# 4516               Men's wear       Innerwear and loungewear
# 4664               Men's wear                        Watches
# 4776               Men's wear                    Accessories
# 4867               Men's wear                    Accessories
# 5061               Men's wear       Personal Care Appliances
# 6562             Women's wear                      Foot wear
# 6653             Women's wear                      Foot wear
# 7498             Women's wear                    Accessories
# ...

# %%
fb_df[fb_df['product_rating'].isnull()]
# Out:
#                    category_1                     category_2  \
# 310    Sports, Books and More              Exercise Fitness
# 607    Sports, Books and More                Food Essentials
# 681    Sports, Books and More                Food Essentials
# 721    Sports, Books and More                Food Essentials
# 1438   Sports, Books and More  Industrial &Scientific tools
# ...                       ...                            ...
# 11420      Home and Furniture               Home Improvement
# 11548      Home and Furniture                     Home Décor
# 11792      Home and Furniture                  Home Lighting
# 11817      Home and Furniture                  Home Lighting
# 12001      Home and Furniture                   Pet Supplies
#
#                             category_3  \
# 310                  Cardio Equipment
# 607               Nuts and Dry Fruits
# 681                        Chocolates
# 721                    Gifting Combos
# ...

# %%
fb_df['product_rating'].fillna('0',inplace=True)
fb_df['product_rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **selling_price**

# %%
fb_df[fb_df['selling_price'].isnull()]
# Out:
#                    category_1                       category_2  \
# 310    Sports, Books and More                Exercise Fitness
# 681    Sports, Books and More                  Food Essentials
# 1578   Sports, Books and More    Industrial &Scientific tools
# 1936              Electronics               Mobile Accessories
# 2156              Electronics              Smart Wearable Tech
# 2164              Electronics              Smart Wearable Tech
# 2653              Electronics                         Speakers
# 3123               Men's wear                        Foot Wear
# 3557               Men's wear                      Bottom Wear
# 4516               Men's wear         Innerwear and loungewear
# 4664               Men's wear                          Watches
# 4776               Men's wear                      Accessories
# 4867               Men's wear                      Accessories
# 5061               Men's wear         Personal Care Appliances
# ...

# %%
fb_df['selling_price'].fillna('0',inplace=True)
fb_df['selling_price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **MRP**

# %%
fb_df[fb_df['mrp'].isnull()]
# Out:
#                    category_1               category_2  \
# 9      Sports, Books and More                   Sports
# 17     Sports, Books and More                   Sports
# 26     Sports, Books and More                   Sports
# 133    Sports, Books and More                   Sports
# 141    Sports, Books and More                   Sports
# ...                       ...                      ...
# 11416      Home and Furniture         Home Improvement
# 11548      Home and Furniture               Home Décor
# 11817      Home and Furniture            Home Lighting
# 11882      Home and Furniture  Festive Decor and Gifts
# 12001      Home and Furniture             Pet Supplies
#
#                     category_3  \
# 9                     Cricket
# 17                    Cricket
# 26                    Cricket
# 133                  Football
# 141                  Football
# ...                        ...
# 11416      Lawn and Gardening
# 11548                  Clocks
# ...

# %%
fb_df['mrp'].fillna('0',inplace=True)

# %% [markdown]
# **seller_name**

# %%
fb_df[fb_df['seller_name'].isnull()]
# Out:
#                    category_1               category_2  \
# 40     Sports, Books and More                   Sports
# 310    Sports, Books and More        Exercise Fitness
# 600    Sports, Books and More          Food Essentials
# 607    Sports, Books and More          Food Essentials
# 681    Sports, Books and More          Food Essentials
# ...                       ...                      ...
# 11792      Home and Furniture            Home Lighting
# 11817      Home and Furniture            Home Lighting
# 11882      Home and Furniture  Festive Decor and Gifts
# 11904      Home and Furniture  Festive Decor and Gifts
# 12001      Home and Furniture             Pet Supplies
#
#                     category_3  \
# 40                  Badminton
# 310          Cardio Equipment
# 600       Nuts and Dry Fruits
# 607       Nuts and Dry Fruits
# 681                Chocolates
# ...                        ...
# 11792              Table Lamp
# 11817            Ceiling Lamp
# ...

# %%
fb_df['seller_name'].fillna('Null',inplace= True)
fb_df['seller_name'].isnull().sum()
# Out:
# 0

# %%
fb_df.drop(['highlights'],axis=1,inplace=True)

# %%
fb_df.drop(['description'],axis=1,inplace=True)

# %%
fb_df.shape
# Out:
# (12041, 10)

# %%
fb_df.category_3.value_counts()[:5]
# Out:
# Innerwear       160
# T -Shirts       120
# Shorts          120
# Sport Shoes      80
# Jeans            80
# Name: category_3, dtype: int64

# %%
fb_df.category_1.value_counts()
# Out:
# Women's wear              2422
# Men's wear                2360
# Bady and Kids             2338
# Home and Furniture        2120
# Sports, Books and More    1820
# Electronics                981
# Name: category_1, dtype: int64

# %%
plt.figure(figsize=(15,5))
vc= fb_df.category_3.value_counts()[0:10]
g=sns.barplot(x=vc.index,y=vc.values,data=fb_df,palette='Set2')

plt.title('Top 10 Product',color='Red',size=20)    
plt.show()

# %%
fb_df.product_rating.value_counts()[:10].sort_values(ascending=False)
# Out:
# 4.0    1697
# 4.1    1692
# 4.2    1495
# 4.3    1343
# 3.9    1234
# 3.8     886
# 4.4     838
# 3.7     542
# 4.5     427
# 3.6     354
# Name: product_rating, dtype: int64

# %%
fb_df.columns
# Out:
# Index(['category_1', 'category_2', 'category_3', 'title', 'product_rating',
#        'selling_price', 'mrp', 'seller_name', 'seller_rating', 'description',
#        'highlights', 'image_links'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
vc=fb_df.product_rating.value_counts()[:10]
g=sns.barplot(x=vc.index , y= vc.values , data=fb_df,palette='Set2')
plt.title('Most Given Ratings',color='Red',size=20)
plt.show()

# %%
fb_df.image_links
# Out:
# 0        https://rukminim1.flixcart.com/image/612/612/x...
# 1        https://rukminim1.flixcart.com/image/612/612/x...
# 2        https://rukminim1.flixcart.com/image/612/612/x...
# 3        https://rukminim1.flixcart.com/image/612/612/k...
# 4        https://rukminim1.flixcart.com/image/612/612/j...
#                                ...
# 12036    https://rukminim1.flixcart.com/image/612/612/x...
# 12037    https://rukminim1.flixcart.com/image/612/612/k...
# 12038    https://rukminim1.flixcart.com/image/612/612/k...
# 12039    https://rukminim1.flixcart.com/image/612/612/j...
# 12040    https://rukminim1.flixcart.com/image/612/612/l...
# Name: image_links, Length: 12041, dtype: object

# %%
fb_df['category_1'].value_counts().plot(kind='pie', autopct='%.2f', figsize=(8,8), title='Category wise products percentage', label='')
# Out:
# <Axes: title={'center': 'Category wise products percentage'}>

# %%
fb_df['category_1'].value_counts().plot(kind='bar', figsize=(8,8), title='Category wise products count')
# Out:
# <Axes: title={'center': 'Category wise products count'}>

# %%
count = fb_df.groupby('category_1')['category_2'].value_counts()
count.name = 'count'
percentage = fb_df.groupby('category_1')['category_2'].value_counts(normalize=True).mul(100).round(1)
percentage.name = 'percentage %'
category_df = pd.concat([count, percentage], axis=1)
category_df
# Out:
#                                    count  percentage %
# category_1    category_2
# Bady and Kids Baby Care              640          27.4
#               Toys                   458          19.6
#               Boys Clothing          200           8.6
#               Girls Clothing         160           6.8
#               Baby Boy Clothing      120           5.1
# ...                                  ...           ...
# Women's wear  Party Dresses           40           1.7
#               Sports Wear             40           1.7
#               Swim  and Beachwear     40           1.7
#               Winter Wear             40           1.7
#               Watches                 22           0.9
#
# [82 rows x 2 columns]

# %%
rating_df = fb_df['product_rating'].value_counts()
rating_df.plot(kind='bar', y='count', xlabel='Product Rating', ylabel='Count', title='Product Rating Count' )
# Out:
# <Axes: title={'center': 'Product Rating Count'}, xlabel='Product Rating', ylabel='Count'>
